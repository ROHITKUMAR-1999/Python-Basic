# %% [markdown]
# # Python Foundation: Topics
# > <p>
#     1. Import the data from files as DataFrame <br/>
#     2. Basic data analysis <br/>
#     3. Data Manipulation / Data Cleaning <br/>
#         - Structural <br/>
#         - Content based <br/>
#     4. Exploratory Analysis
#  </p>

# %% [markdown]
# Objective of the analysis
#
# Availabilty of the data
#     - CREATE RANDOM DATA
#     - DATA IMPORT
#
# Structural understanding
#
# Data understanding
#
# Data Prep:
#     Structural
#         1. Add new columns
#         2. Delete some columns
#         3. Rearrange the columns
#         4. Subsetting (Extracting some columns)
#         5. Rename the columns
#         6. Change the datatypes
#
#     Content based
#         1. Filters
#         2. Sort
#         3. Removal of duplicates
#         4. Data imputation
#             1. Missing value treatment
#             2. Outlier treatment
#         5. Binning or Grouping of the data
#         6. Encoding
#         7. Grouping of the data/ Summaries
#         8. Joins/Merge
#         9. Appending
#
# Exploratory analysis

# %% [markdown]
# ## Data Frames

# %%
import pandas as pd

# %%
# create a dataframe from dict
d1 = {'Emp ID': [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008], 
      'Emp Name': ['John', 'Mac', 'Andrew', 'Andrina', 'Lee', 'Sam', 'Kim', 'Leena'], 
      'Dept': ['Finance', 'HR', 'IT', 'IT', 'IT', 'IT', 'Finance', 'HR'], 
      'Salary': [10000, 12000, 10000, 12000, 14000, 13000, 10000, 18000]}
pd.DataFrame(d1, index = range(1, 9))
# Out:
#    Emp ID Emp Name     Dept  Salary
# 1    1001     John  Finance   10000
# 2    1002      Mac       HR   12000
# 3    1003   Andrew       IT   10000
# 4    1004  Andrina       IT   12000
# 5    1005      Lee       IT   14000
# 6    1006      Sam       IT   13000
# 7    1007      Kim  Finance   10000
# 8    1008    Leena       HR   18000

# %%
# create a dataframe from pandas series
s1 = pd.Series([1001, 1002, 1003,1004, 1005,1007,1010,1003], name = 'EmpId', dtype = int, index = range(1, 9))
s2 = pd.Series(['John', 'Mac', 'Raj', 'Tim', 'Lee', 'Joe', 'Kim', 'Joe'], name = 'EmpName', dtype = object, index = range(1, 9))
s3 = pd.Series(['Finance', 'HR', 'IT', 'IT', 'IT', 'IT', 'Finance', 'HR'], name = 'Dept', dtype = object, index = range(1, 9))
s4 = pd.Series([10000, 12000, 10000, 12000, 14000, 13000, 10000, 18000], name = 'Salary', dtype = int, index = range(1, 9))
pd.DataFrame([s1, s2, s3, s4]).T
# Out:
#   EmpId EmpName     Dept Salary
# 1  1001    John  Finance  10000
# 2  1002     Mac       HR  12000
# 3  1003     Raj       IT  10000
# 4  1004     Tim       IT  12000
# 5  1005     Lee       IT  14000
# 6  1007     Joe       IT  13000
# 7  1010     Kim  Finance  10000
# 8  1003     Joe       HR  18000

# %% [markdown]
# ## Data Import

# %%
# import the pandas package
import pandas as pd

# %%
# Import the data from files as DataFrame
stores = pd.read_csv('Data Sets/Stores.csv')

# %%
score = pd.read_csv('Data Sets/score.csv')

# %%
# import the data
stores = pd.read_csv('Data Sets/stores.csv', sep = ',')

# %%
pwd
# Out:
# 'C:\\Users\\RAHUL CHHIKARA\\Desktop\\PYTHON BASIC\\class 4\\Pandas class files'

# %%
import os

os.chdir('/Users/RAHUL CHHIKARA/Desktop/PYTHON BASIC/class 4/Data Sets')  #change the directory

# %% [markdown]
# ## Basic data analysis
# > 1. Check type of data structure
# > 2. No of dimensions
# > 3. Size of the data
# > 4. Shape of the data
# > 5. Columns
# > 6. Count of columns
# > 7. Data types of each column
# > 8. No of non missing values/records in each column
# > 9. Freq table of data types
# > 10. Memory used
# > 11. See sample records
# > 12. Complete structural summary
# > 13. Data descriptives

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StoreCode        32 non-null     object
#  1   StoreName        32 non-null     object
#  2   StoreType        32 non-null     object
#  3   Location         32 non-null     object
#  4   OperatingCost    32 non-null     float64
#  5   Staff_Cnt        32 non-null     int64
#  6   TotalSales       32 non-null     float64
#  7   Total_Customers  32 non-null     int64
#  8   AcqCostPercust   29 non-null     float64
#  9   BasketSize       32 non-null     float64
#  10  ProfitPercust    32 non-null     float64
#  11  OwnStore         32 non-null     int64
#  12  OnlinePresence   32 non-null     int64
#  13  Tenure           32 non-null     int64
#  14  StoreSegment     32 non-null     int64
# dtypes: float64(5), int64(6), object(4)
# memory usage: 3.9+ KB

# %%
stores.head()  #snapshot of first 5 rows and user input to change the number rows
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46         0               1       4             4
# 1          17.02         0               1       4             4
# 2          18.61         1               1       4             1
# 3          19.44         1               0       3             1
# 4          17.02         0               0       3             2

# %%
stores.tail(10) #snapshot of bottom 5 rows and user input to change the number rows
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 22         80       304.0              150            3.15       3.435
# 23         80       350.0              245            3.73       3.840
# 24         80       400.0              175            3.08       3.845
# 25         40        79.0               66            4.08       1.935
# 26         40       120.3               91            4.43       2.140
# 27         40        95.1              113            3.77       1.513
# 28         80       351.0              264            4.22       3.170
# 29         60       145.0              175            3.62       2.770
# 30         80       301.0              335            3.54       3.570
# 31         40       121.0              109            4.11       2.780
#
#     ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 22          17.30         0               0       3             2
# 23          15.41         0               0       3             4
# 24          17.05         0               0       3             2
# 25          18.90         1               1       4             1
# 26          16.70         0               1       5             2
# 27          16.90         1               1       5             2
# 28          14.50         0               1       5             4
# 29          15.50         0               1       5             4
# 30          14.60         0               1       5             4
# 31          18.60         1               1       4             2

# %%
stores.describe(percentiles=[.1,.2,.3,.99]).T
# Out:
#                  count        mean         std     min      10%      20%  \
# OperatingCost     32.0   20.090625    6.026948  10.400  14.3400   15.200
# Staff_Cnt         32.0   61.875000   17.859216  40.000  40.0000   40.000
# TotalSales        32.0  230.721875  123.938694  71.100  80.6100  120.140
# Total_Customers   32.0  146.687500   68.562868  52.000  66.0000   93.400
# AcqCostPercust    29.0    3.651034    0.532664   2.760   2.9860    3.122
# BasketSize        32.0    3.217250    0.978457   1.513   1.9555    2.349
# ProfitPercust     32.0   17.848750    1.786943  14.500  15.5340   16.734
# OwnStore          32.0    0.437500    0.504016   0.000   0.0000    0.000
# OnlinePresence    32.0    0.406250    0.498991   0.000   0.0000    0.000
# Tenure            32.0    3.687500    0.737804   3.000   3.0000    3.000
# StoreSegment      32.0    2.625000    1.211504   1.000   1.0000    1.200
#
#                      30%      50%        99%      max
# OperatingCost     15.980   19.200   33.43500   33.900
# Staff_Cnt         40.000   60.000   80.00000   80.000
# TotalSales       142.060  196.300  468.28000  472.000
# Total_Customers  106.200  123.000  312.99000  335.000
# AcqCostPercust     3.218    3.730    4.79000    4.930
# BasketSize         2.773    3.325    5.39951    5.424
# ProfitPercust     17.020   17.710   22.06920   22.900
# OwnStore           0.000    0.000    1.00000    1.000
# OnlinePresence     0.000    0.000    1.00000    1.000
# Tenure             3.000    4.000    5.00000    5.000
# StoreSegment       2.000    2.000    4.00000    4.000

# %% [markdown]
# ## Data Manipulation / Data Cleaning - Structural
# > 1. Subsetting (Extracting Column/s)
# > 2. Rearrange/Reorder the column/s
# > 3. Adding new column/s in dataframe
# > 4. Delete column/s from dataframe
# > 5. Rename the column/s
# > 6. Change datatypes

# %% [markdown]
# ### Subsetting: extracting the specific columns from the data

# %%
a = pd.read_excel('Data Sets/Car_data_oth.xlsx')

# %%
a.head(5)
# Out:
#   Manufacturer    Model     Type  MPGcity  MPGhighway             AirBags  \
# 0        Acura  Integra    Small       25          31                None
# 1        Acura   Legend  Midsize       18          25  Driver & Passenger
# 2         Audi       90  Compact       20          26         Driver only
# 3         Audi      100  Midsize       19          26  Driver & Passenger
# 4          BMW     535i  Midsize       22          30         Driver only
#
#   DriveTrain Cylinders  EngineSize  Horsepower  ...  Length  Wheelbase Width  \
# 0      Front         4         1.8         140  ...     177        102    68
# 1      Front         6         3.2         200  ...     195        115    71
# 2      Front         6         2.8         172  ...     180        102    67
# 3      Front         6         2.8         172  ...     193        106    70
# 4       Rear         4         3.5         208  ...     186        109    69
#
#    Turncircle  Rearseatroom  Luggageroom  Weight   Origin           Make  \
# 0          37          26.5         11.0    2705  non-USA  Acura Integra
# 1          38          30.0         15.0    3560  non-USA   Acura Legend
# 2          37          28.0         14.0    3375  non-USA        Audi 90
# 3          37          31.0         17.0    3405  non-USA       Audi 100
# 4          39          27.0         13.0    3640  non-USA       BMW 535i
#
#         Date
# 0 2016-12-01
# 1 2016-12-01
# 2 2016-12-01
# 3 2016-12-01
# 4 2016-12-01
#
# [5 rows x 25 columns]

# %%
# method 1
stores.TotalSales.head()
# Out:
# 0    160.0
# 1    160.0
# 2    108.0
# 3    258.0
# 4    360.0
# Name: TotalSales, dtype: float64

# %%
# method 2
stores[['TotalSales','OperatingCost']].head(2)
# Out:
#    TotalSales  OperatingCost
# 0       160.0           21.0
# 1       160.0           21.0

# %%
# method 3
stores.iloc[:,[1,7,6]].head()
# Out:
#           StoreName  Total_Customers  TotalSales
# 0  Electronics Zone              110       160.0
# 1      Apparel Zone              110       160.0
# 2       Super Bazar               93       108.0
# 3      Super Market              110       258.0
# 4     Central Store              175       360.0

# %%
stores.loc[:, ['TotalSales','OperatingCost']].head(3)
# Out:
#    TotalSales  OperatingCost
# 0       160.0           21.0
# 1       160.0           21.0
# 2       108.0           22.8

# %% [markdown]
# ### Inserting a new column in DF

# %% [raw]
# [] : We can create only one column at a time
# assign() : Can create multiple columns; however column names can't have any special chars not even spaces. _ is an exception
#
# stores.profit ## incorrect if profit column is not in the dataframe

# %%
type(stores.TotalSales)   #renders the pd.series from a dataframe
# Out:
# pandas.core.series.Series

# %%
stores['profit']=stores.TotalSales - stores.OperatingCost
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment  profit
# 0          16.46         0               1       4             4   139.0
# 1          17.02         0               1       4             4   139.0
# 2          18.61         1               1       4             1    85.2
# 3          19.44         1               0       3             1   236.6
# 4          17.02         0               0       3             2   341.3

# %%
stores = stores.assign(profit1 = stores.TotalSales - stores.OperatingCost, profit2 = stores.TotalSales - stores.OperatingCost)
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment  profit  \
# 0          16.46         0               1       4             4   139.0
# 1          17.02         0               1       4             4   139.0
# 2          18.61         1               1       4             1    85.2
# 3          19.44         1               0       3             1   236.6
# 4          17.02         0               0       3             2   341.3
#
#    profit1  profit2
# 0    139.0    139.0
# 1    139.0    139.0
# 2     85.2     85.2
# 3    236.6    236.6
# 4    341.3    341.3

# %% [markdown]
# ### Delete a column

# %%
stores.drop(['Staff_Cnt'], axis = 1, inplace=True)   #default axis is 0 i.e. row level operation
# inplace=True makes the change permanent which otherwise temporary

# %%
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0       160.0              110            3.90       2.620          16.46
# 1       160.0              110            3.90       2.875          17.02
# 2       108.0               93            3.85       2.320          18.61
# 3       258.0              110            3.08       3.215          19.44
# 4       360.0              175            3.15       3.440          17.02
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment  profit  profit1  profit2
# 0         0               1       4             4   139.0    139.0    139.0
# 1         0               1       4             4   139.0    139.0    139.0
# 2         1               1       4             1    85.2     85.2     85.2
# 3         1               0       3             1   236.6    236.6    236.6
# 4         0               0       3             2   341.3    341.3    341.3

# %%
stores = stores.drop(['profit', 'profit1'], axis = 1)

# %%
stores.TotalSales.max()
# Out:
# 472.0

# %%
stores.drop(stores.TotalSales.loc[stores.TotalSales>450].index)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 7        146.7               62            3.69       3.190          20.00
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 11       275.8              180             NaN       4.070          17.40
# 12       275.8              180             NaN       3.730          17.60
# 13       275.8              180             NaN       3.780          18.00
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 23       350.0              245            3.73       3.840          15.41
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 28       351.0              264            4.22       3.170          14.50
# 29       145.0              175            3.62       2.770          15.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 0          0               1       4             4    139.0
# 1          0               1       4             4    139.0
# 2          1               1       4             1     85.2
# 3          1               0       3             1    236.6
# 4          0               0       3             2    341.3
# 5          1               0       3             1    206.9
# 6          0               0       3             4    345.7
# 7          1               0       4             2    122.3
# 8          1               0       4             2    118.0
# 9          1               0       4             4    148.4
# 10         1               0       4             4    149.8
# 11         0               0       3             3    259.4
# 12         0               0       3             3    258.5
# 13         0               0       3             3    260.6
# 16         0               0       3             4    425.3
# 17         1               1       4             1     46.3
# 18         1               1       4             2     45.3
# 19         1               1       4             1     37.2
# 20         1               0       3             1     98.6
# 21         0               0       3             2    302.5
# 22         0               0       3             2    288.8
# 23         0               0       3             4    336.7
# 24         0               0       3             2    380.8
# 25         1               1       4             1     51.7
# 26         0               1       5             2     94.3
# 27         1               1       5             2     64.7
# 28         0               1       5             4    335.2
# 29         0               1       5             4    125.3
# 30         0               1       5             4    286.0
# 31         1               1       4             2     99.6

# %% [markdown]
# ### Rename the columns

# %%
stores.rename(columns={'Total_Customers':'TotalCustomers','Staff_Cnt':'StaffCount'}).head()
# stores.rename?
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    TotalSales  TotalCustomers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0       160.0             110            3.90       2.620          16.46
# 1       160.0             110            3.90       2.875          17.02
# 2       108.0              93            3.85       2.320          18.61
# 3       258.0             110            3.08       3.215          19.44
# 4       360.0             175            3.15       3.440          17.02
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 0         0               1       4             4    139.0
# 1         0               1       4             4    139.0
# 2         1               1       4             1     85.2
# 3         1               0       3             1    236.6
# 4         0               0       3             2    341.3

# %% [markdown]
# ## Data Manipulation / Data Cleaning - Content based
# > 1. Filters
# > 2. Sorting
# > 3. Removal of duplicates
# > 4. Data imputaion
# > 5. Encoding
# > 6. Binning/creating new grouped variables
# > 7. Grouping/Aggregations
# > 8. Joins/Merge
# > 9. Data append
# > 10. Summaries

# %% [markdown]
# ### Filtering:
# > 1. Get records from stores where Location is Delhi
# > 2. Records from Kolkata where TotalSales > 100 and < 300
# > 3. All store codes and store types from Chennai where OperatingCost > 15

# %% [markdown]
# ### Filters

# %%
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0       160.0              110            3.90       2.620          16.46
# 1       160.0              110            3.90       2.875          17.02
# 2       108.0               93            3.85       2.320          18.61
# 3       258.0              110            3.08       3.215          19.44
# 4       360.0              175            3.15       3.440          17.02
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 0         0               1       4             4    139.0
# 1         0               1       4             4    139.0
# 2         1               1       4             1     85.2
# 3         1               0       3             1    236.6
# 4         0               0       3             2    341.3

# %%
# Q1: Get records from stores where Location is Delhi
stores[stores.Location == 'Delhi']
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
# 5    STR106      Apparel Zone       Apparel    Delhi           18.1
# 6    STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7    STR108     Digital Bazar  Electronincs    Delhi           24.4
#
#    TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0       160.0              110            3.90       2.620          16.46
# 1       160.0              110            3.90       2.875          17.02
# 2       108.0               93            3.85       2.320          18.61
# 3       258.0              110            3.08       3.215          19.44
# 4       360.0              175            3.15       3.440          17.02
# 5       225.0              105            2.76       3.460          20.22
# 6       360.0              245            3.21       3.570          15.84
# 7       146.7               62            3.69       3.190          20.00
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 0         0               1       4             4    139.0
# 1         0               1       4             4    139.0
# 2         1               1       4             1     85.2
# 3         1               0       3             1    236.6
# 4         0               0       3             2    341.3
# 5         1               0       3             1    206.9
# 6         0               0       3             4    345.7
# 7         1               0       4             2    122.3

# %%
# Q2: Records from Kolkata where TotalSales > 100 and < 300
stores[(stores.Location=="Kolkata") & (stores.TotalSales > 100) & (stores['TotalSales'] < 300)]
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  TotalSales  \
# 26    STR127    Super Bazar  Super Market  Kolkata           26.0       120.3
# 29    STR130   Apparel Zone       Apparel  Kolkata           19.7       145.0
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4       121.0
#
#     Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  OwnStore  \
# 26               91            4.43        2.14           16.7         0
# 29              175            3.62        2.77           15.5         0
# 31              109            4.11        2.78           18.6         1
#
#     OnlinePresence  Tenure  StoreSegment  profit2
# 26               1       5             2     94.3
# 29               1       5             4    125.3
# 31               1       4             2     99.6

# %%
# Q3: All store codes and store types from Chennai where OperatingCost > 15
stores.loc[(stores.Location  == 'Chennai') & (stores.OperatingCost>15),['Location','StoreCode','StoreType']]
# Out:
#    Location StoreCode     StoreType
# 8   Chennai    STR109  Electronincs
# 9   Chennai    STR110       Apparel
# 10  Chennai    STR111  Super Market
# 11  Chennai    STR112  Super Market
# 12  Chennai    STR113  Super Market
# 13  Chennai    STR114       Apparel

# %% [markdown]
# ### Sorting
# > - sort data acc to one column  [Location asc]
# > - sort data acc to one column  [TotalSales desc]
# > - sort data acc to two columns [Location, OperatingCost asc]
# > - sort data acc to two columns [Location, TotalSales desc]
# > - sort data acc to two columns [Location in asc, TotalSales in desc]

# %%
stores.sort_values('Location', inplace=True)
stores.head()
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  TotalSales  \
# 15    STR116  Digital Bazar  Electronincs  Chennai           10.4       460.0
# 14    STR115  Fashion Bazar       Apparel  Chennai           10.4       472.0
# 13    STR114   Apparel Zone       Apparel  Chennai           15.2       275.8
# 12    STR113  Central Store  Super Market  Chennai           17.3       275.8
# 11    STR112   Super Market  Super Market  Chennai           16.4       275.8
#
#     Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  OwnStore  \
# 15              215            3.00       5.424          17.82         0
# 14              205            2.93       5.250          17.98         0
# 13              180             NaN       3.780          18.00         0
# 12              180             NaN       3.730          17.60         0
# 11              180             NaN       4.070          17.40         0
#
#     OnlinePresence  Tenure  StoreSegment  profit2
# 15               0       3             4    449.6
# 14               0       3             4    461.6
# 13               0       3             3    260.6
# 12               0       3             3    258.5
# 11               0       3             3    259.4

# %%
stores.sort_index()
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 7        146.7               62            3.69       3.190          20.00
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 11       275.8              180             NaN       4.070          17.40
# 12       275.8              180             NaN       3.730          17.60
# 13       275.8              180             NaN       3.780          18.00
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 23       350.0              245            3.73       3.840          15.41
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 28       351.0              264            4.22       3.170          14.50
# 29       145.0              175            3.62       2.770          15.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 0          0               1       4             4    139.0
# 1          0               1       4             4    139.0
# 2          1               1       4             1     85.2
# 3          1               0       3             1    236.6
# 4          0               0       3             2    341.3
# 5          1               0       3             1    206.9
# 6          0               0       3             4    345.7
# 7          1               0       4             2    122.3
# 8          1               0       4             2    118.0
# 9          1               0       4             4    148.4
# 10         1               0       4             4    149.8
# 11         0               0       3             3    259.4
# 12         0               0       3             3    258.5
# 13         0               0       3             3    260.6
# 14         0               0       3             4    461.6
# 15         0               0       3             4    449.6
# 16         0               0       3             4    425.3
# 17         1               1       4             1     46.3
# 18         1               1       4             2     45.3
# 19         1               1       4             1     37.2
# 20         1               0       3             1     98.6
# 21         0               0       3             2    302.5
# 22         0               0       3             2    288.8
# 23         0               0       3             4    336.7
# 24         0               0       3             2    380.8
# 25         1               1       4             1     51.7
# 26         0               1       5             2     94.3
# 27         1               1       5             2     64.7
# 28         0               1       5             4    335.2
# 29         0               1       5             4    125.3
# 30         0               1       5             4    286.0
# 31         1               1       4             2     99.6

# %%
stores.sort_values('Location',ascending=False)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 20       120.1               97            3.70       2.465          20.01
# 22       304.0              150            3.15       3.435          17.30
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 21       318.0              150            2.76       3.520          16.87
# 23       350.0              245            3.73       3.840          15.41
# 28       351.0              264            4.22       3.170          14.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 29       145.0              175            3.62       2.770          15.50
# 7        146.7               62            3.69       3.190          20.00
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 0        160.0              110            3.90       2.620          16.46
# 14       472.0              205            2.93       5.250          17.98
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 11       275.8              180             NaN       4.070          17.40
# 12       275.8              180             NaN       3.730          17.60
# 13       275.8              180             NaN       3.780          18.00
# 15       460.0              215            3.00       5.424          17.82
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 20         1               0       3             1     98.6
# 22         0               0       3             2    288.8
# 16         0               0       3             4    425.3
# 17         1               1       4             1     46.3
# 18         1               1       4             2     45.3
# 19         1               1       4             1     37.2
# 21         0               0       3             2    302.5
# 23         0               0       3             4    336.7
# 28         0               1       5             4    335.2
# 30         0               1       5             4    286.0
# 31         1               1       4             2     99.6
# 24         0               0       3             2    380.8
# 25         1               1       4             1     51.7
# 26         0               1       5             2     94.3
# 27         1               1       5             2     64.7
# 29         0               1       5             4    125.3
# 7          1               0       4             2    122.3
# 1          0               1       4             4    139.0
# 2          1               1       4             1     85.2
# 3          1               0       3             1    236.6
# 4          0               0       3             2    341.3
# 5          1               0       3             1    206.9
# 6          0               0       3             4    345.7
# 0          0               1       4             4    139.0
# 14         0               0       3             4    461.6
# 8          1               0       4             2    118.0
# 9          1               0       4             4    148.4
# 10         1               0       4             4    149.8
# 11         0               0       3             3    259.4
# 12         0               0       3             3    258.5
# 13         0               0       3             3    260.6
# 15         0               0       3             4    449.6

# %%
stores.sort_values("TotalSales", ascending = True).head()
# Out:
#    StoreCode     StoreName     StoreType Location  OperatingCost  TotalSales  \
# 19    STR120  Super Market  Super Market   Mumbai           33.9        71.1
# 18    STR119   Super Bazar  Super Market   Mumbai           30.4        75.7
# 17    STR118  Apparel Zone       Apparel   Mumbai           32.4        78.7
# 25    STR126  Apparel Zone       Apparel  Kolkata           27.3        79.0
# 27    STR128  Super Market  Super Market  Kolkata           30.4        95.1
#
#     Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  OwnStore  \
# 19               65            4.22       1.835          19.90         1
# 18               52            4.93       1.615          18.52         1
# 17               66            4.08       2.200          19.47         1
# 25               66            4.08       1.935          18.90         1
# 27              113            3.77       1.513          16.90         1
#
#     OnlinePresence  Tenure  StoreSegment  profit2
# 19               1       4             1     37.2
# 18               1       4             2     45.3
# 17               1       4             1     46.3
# 25               1       4             1     51.7
# 27               1       5             2     64.7

# %%
stores.sort_values(['Location','OperatingCost'], ascending=False)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 19        71.1               65            4.22       1.835          19.90
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 16       440.0              230            3.23       5.345          17.42
# 23       350.0              245            3.73       3.840          15.41
# 27        95.1              113            3.77       1.513          16.90
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 31       121.0              109            4.11       2.780          18.60
# 29       145.0              175            3.62       2.770          15.50
# 24       400.0              175            3.08       3.845          17.05
# 28       351.0              264            4.22       3.170          14.50
# 30       301.0              335            3.54       3.570          14.60
# 7        146.7               62            3.69       3.190          20.00
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 12       275.8              180             NaN       3.730          17.60
# 11       275.8              180             NaN       4.070          17.40
# 13       275.8              180             NaN       3.780          18.00
# 15       460.0              215            3.00       5.424          17.82
# 14       472.0              205            2.93       5.250          17.98
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 19         1               1       4             1     37.2
# 17         1               1       4             1     46.3
# 18         1               1       4             2     45.3
# 20         1               0       3             1     98.6
# 21         0               0       3             2    302.5
# 22         0               0       3             2    288.8
# 16         0               0       3             4    425.3
# 23         0               0       3             4    336.7
# 27         1               1       5             2     64.7
# 25         1               1       4             1     51.7
# 26         0               1       5             2     94.3
# 31         1               1       4             2     99.6
# 29         0               1       5             4    125.3
# 24         0               0       3             2    380.8
# 28         0               1       5             4    335.2
# 30         0               1       5             4    286.0
# 7          1               0       4             2    122.3
# 2          1               1       4             1     85.2
# 3          1               0       3             1    236.6
# 0          0               1       4             4    139.0
# 1          0               1       4             4    139.0
# 4          0               0       3             2    341.3
# 5          1               0       3             1    206.9
# 6          0               0       3             4    345.7
# 8          1               0       4             2    118.0
# 9          1               0       4             4    148.4
# 10         1               0       4             4    149.8
# 12         0               0       3             3    258.5
# 11         0               0       3             3    259.4
# 13         0               0       3             3    260.6
# 15         0               0       3             4    449.6
# 14         0               0       3             4    461.6

# %%
stores.sort_values(["Location", "TotalSales"], ascending=False)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 16       440.0              230            3.23       5.345          17.42
# 23       350.0              245            3.73       3.840          15.41
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 20       120.1               97            3.70       2.465          20.01
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 24       400.0              175            3.08       3.845          17.05
# 28       351.0              264            4.22       3.170          14.50
# 30       301.0              335            3.54       3.570          14.60
# 29       145.0              175            3.62       2.770          15.50
# 31       121.0              109            4.11       2.780          18.60
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 25        79.0               66            4.08       1.935          18.90
# 6        360.0              245            3.21       3.570          15.84
# 4        360.0              175            3.15       3.440          17.02
# 3        258.0              110            3.08       3.215          19.44
# 5        225.0              105            2.76       3.460          20.22
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 7        146.7               62            3.69       3.190          20.00
# 2        108.0               93            3.85       2.320          18.61
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 13       275.8              180             NaN       3.780          18.00
# 12       275.8              180             NaN       3.730          17.60
# 11       275.8              180             NaN       4.070          17.40
# 10       167.6              123            3.92       3.440          18.90
# 9        167.6              123            3.92       3.440          18.30
# 8        140.8               95            3.92       3.150          22.90
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 16         0               0       3             4    425.3
# 23         0               0       3             4    336.7
# 21         0               0       3             2    302.5
# 22         0               0       3             2    288.8
# 20         1               0       3             1     98.6
# 17         1               1       4             1     46.3
# 18         1               1       4             2     45.3
# 19         1               1       4             1     37.2
# 24         0               0       3             2    380.8
# 28         0               1       5             4    335.2
# 30         0               1       5             4    286.0
# 29         0               1       5             4    125.3
# 31         1               1       4             2     99.6
# 26         0               1       5             2     94.3
# 27         1               1       5             2     64.7
# 25         1               1       4             1     51.7
# 6          0               0       3             4    345.7
# 4          0               0       3             2    341.3
# 3          1               0       3             1    236.6
# 5          1               0       3             1    206.9
# 0          0               1       4             4    139.0
# 1          0               1       4             4    139.0
# 7          1               0       4             2    122.3
# 2          1               1       4             1     85.2
# 14         0               0       3             4    461.6
# 15         0               0       3             4    449.6
# 13         0               0       3             3    260.6
# 12         0               0       3             3    258.5
# 11         0               0       3             3    259.4
# 10         1               0       4             4    149.8
# 9          1               0       4             4    148.4
# 8          1               0       4             2    118.0

# %%
stores.sort_values(["Location", "TotalSales"], ascending = [True, False]).head(10)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 4     STR105     Central Store  Super Market    Delhi           18.7
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 13       275.8              180             NaN       3.780          18.00
# 12       275.8              180             NaN       3.730          17.60
# 11       275.8              180             NaN       4.070          17.40
# 10       167.6              123            3.92       3.440          18.90
# 9        167.6              123            3.92       3.440          18.30
# 8        140.8               95            3.92       3.150          22.90
# 6        360.0              245            3.21       3.570          15.84
# 4        360.0              175            3.15       3.440          17.02
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment  profit2
# 14         0               0       3             4    461.6
# 15         0               0       3             4    449.6
# 13         0               0       3             3    260.6
# 12         0               0       3             3    258.5
# 11         0               0       3             3    259.4
# 10         1               0       4             4    149.8
# 9          1               0       4             4    148.4
# 8          1               0       4             2    118.0
# 6          0               0       3             4    345.7
# 4          0               0       3             2    341.3

# %% [markdown]
# ### Remove Duplicates

# %%
score = pd.read_csv("Data Sets/Score.csv")
score
# Out:
#       Student  Section  Test1  Test2  Final
# 0   Capalleti        1     94     91     87
# 1      Dubose        2     51     65     91
# 2      Engles        1     95     97     97
# 3       Grant        2     63     75     80
# 4     Krupski        2     80     76     71
# 5   Lundsford        1     92     40     86
# 6      Mcbane        1     75     78     72
# 7   Capalleti        1     94     65     87
# 8      Dubose        2     51     65     91
# 9      Engles        1     95     97     97
# 10      Grant        2     63     75     80
# 11    Krupski        2     80     76     71
# 12  Lundsford        1     92     40     86
# 13     Mcbane        1     75     78     72

# %%
#score['isdup'] = score.duplicated()          #finding duplicated based same value across all columns
score['isdup'] = score.duplicated(['Student']) #finding duplicated based on a particular column
#score['isdup'] = score.Student.duplicated()  #finding duplicated based on a particular column
score
#score.duplicated?
# Out:
#       Student  Section  Test1  Test2  Final  isdup
# 0   Capalleti        1     94     91     87  False
# 1      Dubose        2     51     65     91  False
# 2      Engles        1     95     97     97  False
# 3       Grant        2     63     75     80  False
# 4     Krupski        2     80     76     71  False
# 5   Lundsford        1     92     40     86  False
# 6      Mcbane        1     75     78     72  False
# 7   Capalleti        1     94     65     87   True
# 8      Dubose        2     51     65     91   True
# 9      Engles        1     95     97     97   True
# 10      Grant        2     63     75     80   True
# 11    Krupski        2     80     76     71   True
# 12  Lundsford        1     92     40     86   True
# 13     Mcbane        1     75     78     72   True

# %%
score[score.duplicated()]
# Out:
#       Student  Section  Test1  Test2  Final
# 8      Dubose        2     51     65     91
# 9      Engles        1     95     97     97
# 10      Grant        2     63     75     80
# 11    Krupski        2     80     76     71
# 12  Lundsford        1     92     40     86
# 13     Mcbane        1     75     78     72

# %%
score.loc[score.duplicated(),:]
# Out:
#       Student  Section  Test1  Test2  Final
# 8      Dubose        2     51     65     91
# 9      Engles        1     95     97     97
# 10      Grant        2     63     75     80
# 11    Krupski        2     80     76     71
# 12  Lundsford        1     92     40     86
# 13     Mcbane        1     75     78     72

# %%
score.loc[-score.Student.duplicated(),:]
# Out:
#      Student  Section  Test1  Test2  Final
# 0  Capalleti        1     94     91     87
# 1     Dubose        2     51     65     91
# 2     Engles        1     95     97     97
# 3      Grant        2     63     75     80
# 4    Krupski        2     80     76     71
# 5  Lundsford        1     92     40     86
# 6     Mcbane        1     75     78     72

# %% [markdown]
# ### Missing Data in Numeric Variables
#
#     Fill missing values with the
#     - Drop rows where data is missing (if you have LOTS of data >1 mn rows)
#     - Mean (if the distribution is symmetric)
#     - Median (if the distribution is skewed)
#     - Zeros (for data that indicates absence of a metric.)
#     - Use predictive modelling techniques to get the app value of the missing
#
# ### Missing Data in Object Variables
# Fill missing values with - the Mode

# %% [markdown]
# ### Connect to the RDBMS Servers

# %%
import pyodbc

# %%
sql_conn = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL Server};SERVER=SBAL;DATABASE=db_mar_19;Trusted_Connection=yes')

# %%
query = 'SELECT * FROM TBL_CUSTOMER;'
df = pd.read_sql(query, sql_conn)
#df.head()
